# %%
 ,\e4essaAAxc/dccx`print("Hello, World!")
# Out:
#   Cell In[1], line 1
#     \e4essaAAxc/dccx`print("Hello,("World!")")
#      ^
# SyntaxError: unexpected character after line continuation character

# %%
name= "Hart" # name is a string
print(type(name))

# %%
x = 5              # assigns the integer 5 to the variable x
name = "hart"      # assigns the string "Hart" to the variable name
is_fellow = True   # assigns the boolean true to the variable is_fellow
height = 1.75      #assigns the float 1.75 to the variable height

# %%
print(x)

# %%
print(name)

# %%
name = "hart"
Name = "bassey"

# %%
print(name)
print(Name)

# %%
Identity = "deborah"

# %%
print(Identity)

# %%
result = 5+5

# %%
print(result)

# %%
result = 15//2

# %%
print(result)

# %%
5==5

# %%
5!=3

# %%
(5>3) and (10>5)

# %%
age = 18
if age >= 18:
    print("you are eligible to  vote")

# %%
score = 85
if score>= 90:
    print("grade: A")
elif score >=80:
    print("grade:b")

# %%
score = 80
if score>= 70:
    print("grade: A")
elif score >=60:
    print("grade:b")

# %%
for i in range(5):
    print(i)

# %%
Fruits=["apple","cherry","orange"]
for fruit in Fruits:
    print(fruit)

# %%
num = 2
while num <= 10:
    print (num)
    num += 2

# %%
count = 1
while count <= 5:
    print(count)
    count +=1

# %%
name ="pyton"
for i in name:
    print(i)

# %%
names = ["Hart","Joseph","Onyi"]
numbers = [1,2,3,4,5]
mixed = ["hello", 42, 3.14, True]
print(names)

# %%
print(mixed)

# %%
print(names[0])
print(numbers[1])
print(mixed[2])

# %%
print(names[-1])
print(numbers[-2])
print(mixed[-3])

# %%
names = ["Hart","Joseph","Onyi"]
names[1] = "miracle"
print(names)

# %%
names = ["Hart","Joseph","Onyi"]
names[-1] = "joy"
print(names)

# %%
names = ["Hart","Joseph","Onyi"]
names.append("miracle")
print(names)

# %%
names = ["Hart","Joseph","Onyi"]
names.insert(2, "miracle")
print(names)

# %%
names = ["Hart","Joseph","Onyi"]
names.remove("Joseph")
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
first_name = names.pop()
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
second_name = names.pop(2)
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
first_name = names.pop(1)
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
names.pop(1)
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
names.clear()
print(names)

# %%
names = ["Hart","Joseph","Onyi","Joy"]
numbers =[ 1, 2, 3, 4, 5, 6, 7,]
combine_list = names + numbers
print(combine_list)

# %%
print(combine_list[1:4])

# %%
print(combine_list[:6])

# %%
print(combine_list[::2])

# %%
print(combine_list[::-1])

# %%
print(combine_list[::-2])

# %%
print(combine_list[:-1])

# %%
combine_list = ['Hart', 'Joseph', 'Onyi', 'Joy', 1, 2, 3, 4, 5, 6, 7]
print(5 in combine_list)

# %%
combine_list = ['Hart', 'Joseph', 'Onyi', 'Joy', 1, 2, 3, 4, 5, 6, 7]
print(2 not in combine_list)

# %%
print("mary" in combine_list)

# %%
number = [45,25,50,90,100,35,65,72,1,2,15,7,6]
print(min(number))

# %%
print(max(number))

# %%
print(sum(number))

# %%
sorted_number=number.sort()
print(sorted_number)

# %%
sorted_number= sorted(number)
print(sorted_number)

# %%
sorted_number= sorted(number, reverse= True)
print(sorted_number)

# %%
number=(18,19,23,45,90)
print(number)

# %%
 print(number[2])

# %%
person = {"name": "deborah", "phone_no": "08116339820", "age": 20,"city":"lagos"}
print(person)

# %%
print(person["city"])

# %%
print(person["name"])

# %%
 person["joy"] = 24
print(person)

# %%
person["name"] = "ayo"
print(person)

# %%
if"age"in person:
    print("yes")

# %%
if "class" in person:
    print("not recorded")

# %%
my_set = {1,1,2,2,5,4,7,8,8,9,9,5}
print(my_set)

# %%
my_set.add(6)
print(numbers)

# %%
def greet():
    print("hello, welome home")

# %%
greet()

# %%
def greet(name):
    print ("you're beautiful")

# %%
greet("ife")

# %%
def introduce_person(Name, age, city):
    print("hi! my name is"  +  Name)
    print("i am"  +  str(age) +  "years old")
    print("i live in"  +  city)

introduce_person("bolu", 23 , "lagos")

# %%
introduce_person("ayo", 21 , "aie")

# %%
 def add_num(x,y):
     return(x +y)

# %%
result = add_num(4, 6)
print(result)

# %%
print(result *3)

# %%
print(result *5)

# %%
  def add_num(a,b):
      return (a*b)

# %%
result= add_num(6,5)
print(result)

# %%
file = open("Grace academy.txt","w")
file.write("this academy changes life.")
file.close()

# %%
file = open("Grace academy.txt","r")
print(file.read())
file.close()

# %%
file = open("Grace academy.txt","a")
file.write("we are going global.")
file.close()
